# %% [markdown]
# # Load all population Data

# %%
import pandas as pd

pop_2010_2019_df = pd.read_csv('original_data/population-2010-2019.csv',skiprows=1,header = 1)

pop_2010_2019_df
# Out:
#        LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0          4          Afghanistan  2010.0    0-4          0.0         5.0
# 1          8              Albania  2010.0    0-4          0.0         5.0
# 2         12              Algeria  2010.0    0-4          0.0         5.0
# 3         24               Angola  2010.0    0-4          0.0         5.0
# 4         28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 41790    430              Liberia  2019.0   100+        100.0        -1.0
# 41791    882                Samoa  2019.0   100+        100.0        -1.0
# 41792    768                 Togo  2019.0   100+        100.0        -1.0
# 41793    776                Tonga  2019.0   100+        100.0        -1.0
# 41794    548              Vanuatu  2019.0   100+        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# 0      2715.070   2600.535  5315.605
# ...

# %% [markdown]
# # Find data details

# %% [markdown]
# ## 1. Essential Properties (Attributes)
#   Properties tell you something about the data without changing it. You don't use parentheses () with these.
#
#   | Property | Description | SQL/Power BI Equivalent |
# | :--- | :--- | :--- |
# | **`.shape`** | Returns a tuple (rows, columns). | Table Row/Col count |
# | **`.columns`** | Returns the list of column names. | Header Row |
# | **`.index`** | Returns the row labels (usually 0, 1, 2...). | Primary Key/Index |
# | **`.dtypes`** | Shows the data type of each column. | Schema / Data Category |
# | **`.size`** | Total number of elements (rows × columns). | Total Cell Count |
# | **`.values`** | Converts the data into a NumPy array. | Raw Data Array |

# %%
pop_2010_2019_df.shape
# Out:
# (41795, 9)

# %%
pop_2010_2019_df.columns
# Out:
# Index(['LocID', 'Location', 'Time', 'AgeGrp', 'AgeGrpStart', 'AgeGrpSpan',
#        'PopMale', 'PopFemale', 'PopTotal'],
#       dtype='str')

# %%
pop_2010_2019_df.index
# Out:
# RangeIndex(start=0, stop=41795, step=1)

# %%
pop_2010_2019_df.dtypes
# Out:
# LocID            int64
# Location           str
# Time           float64
# AgeGrp             str
# AgeGrpStart    float64
# AgeGrpSpan     float64
# PopMale        float64
# PopFemale      float64
# PopTotal       float64
# dtype: object

# %%
pop_2010_2019_df.size
# Out:
# 376155

# %%
pop_2010_2019_df.values
# Out:
# array([[4, 'Afghanistan', 2010.0, ..., 2715.07, 2600.535, 5315.605],
#        [8, 'Albania', 2010.0, ..., 92.622, 81.239, 173.861],
#        [12, 'Algeria', 2010.0, ..., 1966.415, 1885.869, 3852.284],
#        ...,
#        [768, 'Togo', 2019.0, ..., 0.0, 0.0, 0.0],
#        [776, 'Tonga', 2019.0, ..., 0.0, 0.0, 0.0],
#        [548, 'Vanuatu', 2019.0, ..., 0.0, 0.0, 0.0]],
#       shape=(41795, 9), dtype=object)

# %% [markdown]
# ## 2. Essential Methods
# Methods perform an action or calculation on the data. These always use parentheses ().
#
# **A. Data Exploration**
# * **.head(n) / .tail(n):** View the first or last (n) rows.
# * **.info():** A "health check" for your data. Shows non-null counts and memory usage.
# * **.describe():** Generates summary statistics (mean, std, min, max, quartiles).
#
# -Power BI Equivalent: Column Statistics in Power Query.

# %%
pop_2010_2019_df.head(10)
# Out:
#    LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# 5     32            Argentina  2010.0    0-4          0.0         5.0
# 6     51              Armenia  2010.0    0-4          0.0         5.0
# 7    533                Aruba  2010.0    0-4          0.0         5.0
# 8     36            Australia  2010.0    0-4          0.0         5.0
# 9     40              Austria  2010.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  2715.070   2600.535  5315.605
# 1    92.622     81.239   173.861
# 2  1966.415   1885.869  3852.284
# 3  2233.041   2239.035  4472.076
# ...

# %%
pop_2010_2019_df.tail(10)
# Out:
#        LocID           Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 41785    226  Equatorial Guinea  2019.0   100+        100.0        -1.0
# 41786    266              Gabon  2019.0   100+        100.0        -1.0
# 41787    270             Gambia  2019.0   100+        100.0        -1.0
# 41788    624      Guinea-Bissau  2019.0   100+        100.0        -1.0
# 41789    414             Kuwait  2019.0   100+        100.0        -1.0
# 41790    430            Liberia  2019.0   100+        100.0        -1.0
# 41791    882              Samoa  2019.0   100+        100.0        -1.0
# 41792    768               Togo  2019.0   100+        100.0        -1.0
# 41793    776              Tonga  2019.0   100+        100.0        -1.0
# 41794    548            Vanuatu  2019.0   100+        100.0        -1.0
#
#        PopMale  PopFemale  PopTotal
# 41785      0.0        0.0       0.0
# 41786      0.0        0.0       0.0
# 41787      0.0        0.0       0.0
# ...

# %%
pop_2010_2019_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41795 entries, 0 to 41794
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        41795 non-null  int64
#  1   Location     41795 non-null  str
#  2   Time         41791 non-null  float64
#  3   AgeGrp       41791 non-null  str
#  4   AgeGrpStart  41791 non-null  float64
#  5   AgeGrpSpan   41791 non-null  float64
#  6   PopMale      41791 non-null  float64
#  7   PopFemale    41791 non-null  float64
#  8   PopTotal     41791 non-null  float64
# dtypes: float64(6), int64(1), str(2)
# memory usage: 2.9 MB

# %%
pop_2010_2019_df.describe()
# Out:
#               LocID          Time   AgeGrpStart    AgeGrpSpan       PopMale  \
# count  41795.000000  41791.000000  41791.000000  41791.000000  41791.000000
# mean     443.678789   2014.499892     49.998804      4.714293    878.579738
# std      275.319329      2.872366     30.277491      1.277754   4280.236638
# min        4.000000   2010.000000      0.000000     -1.000000      0.000000
# 25%      218.000000   2012.000000     25.000000      5.000000      8.154500
# 50%      428.000000   2014.000000     50.000000      5.000000     87.610000
# 75%      662.000000   2017.000000     75.000000      5.000000    415.091000
# max     1835.000000   2019.000000    100.000000      5.000000  67528.067000
#
#           PopFemale       PopTotal
# count  41791.000000   41791.000000
# mean     863.585655    1742.165369
# std     3978.122164    8255.389397
# min        0.000000       0.000000
# 25%       10.138500      18.930500
# 50%       99.380000     190.152000
# ...

# %% [markdown]
# **B. Data Selection & Filtering**
# * **.loc[]:** Access rows and columns by label (e.g., df.loc[0, 'Name']). --- only works on index col..far left col
#
# * **.iloc[]:** Access rows and columns by integer position (e.g., df.iloc[0, 1]).
#
# * **.drop():** Removes specified rows or columns.

# %%
pop_2010_2019_df.loc[226]
# Out:
# LocID                72
# Location       Botswana
# Time             2010.0
# AgeGrp          05. Sep
# AgeGrpStart         5.0
# AgeGrpSpan          5.0
# PopMale         116.448
# PopFemale       114.062
# PopTotal         230.51
# Name: 226, dtype: object

# %%
print(pop_2010_2019_df.iloc[1])
print("=="*12)
print(pop_2010_2019_df.iloc[0])
# Out:
# LocID                8
# Location       Albania
# Time            2010.0
# AgeGrp             0-4
# AgeGrpStart        0.0
# AgeGrpSpan         5.0
# PopMale         92.622
# PopFemale       81.239
# PopTotal       173.861
# Name: 1, dtype: object
# ...
# LocID                    4
# Location       Afghanistan
# Time                2010.0
# AgeGrp                 0-4
# AgeGrpStart            0.0
# AgeGrpSpan             5.0
# PopMale            2715.07
# PopFemale         2600.535
# PopTotal          5315.605
# Name: 0, dtype: object

# %% [markdown]
# **C. Data Cleaning**
# * **.isnull() / .notnull():** Returns a boolean mask for missing values.
#
# * **.fillna(value):** Replaces NaN values with a specific value.
#
# --SQL Equivalent: COALESCE(column, value).
#
# * **.dropna():** Deletes rows/columns containing missing values.
#
# * **.rename():** Changes column or index names.

# %%
pop_2010_2019_df.isnull()
# Out:
#        LocID  Location   Time  AgeGrp  AgeGrpStart  AgeGrpSpan  PopMale  \
# 0      False     False  False   False        False       False    False
# 1      False     False  False   False        False       False    False
# 2      False     False  False   False        False       False    False
# 3      False     False  False   False        False       False    False
# 4      False     False  False   False        False       False    False
# ...      ...       ...    ...     ...          ...         ...      ...
# 41790  False     False  False   False        False       False    False
# 41791  False     False  False   False        False       False    False
# 41792  False     False  False   False        False       False    False
# 41793  False     False  False   False        False       False    False
# 41794  False     False  False   False        False       False    False
#
#        PopFemale  PopTotal
# 0          False     False
# 1          False     False
# ...

# %%
pop_2010_2019_df.isnull().any()
# Out:
# LocID          False
# Location       False
# Time            True
# AgeGrp          True
# AgeGrpStart     True
# AgeGrpSpan      True
# PopMale         True
# PopFemale       True
# PopTotal        True
# dtype: bool

# %%
pop_2010_2019_df.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41790    False
# 41791    False
# 41792    False
# 41793    False
# 41794    False
# Length: 41795, dtype: bool

# %% [markdown]
# ## Clean1

# %%
pop_2010_2019_df[pop_2010_2019_df.isnull().any(axis = 1)]  ## how to keep this in mind
# Out:
#     LocID Location  Time AgeGrp  AgeGrpStart  AgeGrpSpan  PopMale  PopFemale  \
# 40    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 41    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 42    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 43    111    China   NaN    NaN          NaN         NaN      NaN        NaN
#
#     PopTotal
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN

# %%
pop_2010_2019_df.dropna(inplace=True) ## inplace makes method to work in place

# %%
pop_2010_2019_df[pop_2010_2019_df.isnull().any(axis = 1)]  ## This tells us nulls are removed
# Out:
# Empty DataFrame
# Columns: [LocID, Location, Time, AgeGrp, AgeGrpStart, AgeGrpSpan, PopMale, PopFemale, PopTotal]
# Index: []

# %%
pop_2010_2019_df.head(10)
# Out:
#    LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# 5     32            Argentina  2010.0    0-4          0.0         5.0
# 6     51              Armenia  2010.0    0-4          0.0         5.0
# 7    533                Aruba  2010.0    0-4          0.0         5.0
# 8     36            Australia  2010.0    0-4          0.0         5.0
# 9     40              Austria  2010.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  2715.070   2600.535  5315.605
# 1    92.622     81.239   173.861
# 2  1966.415   1885.869  3852.284
# 3  2233.041   2239.035  4472.076
# ...

# %%
pop_2010_2019_df.rename(columns={'Time':'Year','PopMale':'Male','PopFemale':'Female'},inplace=True)
pop_2010_2019_df
# Out:
#        LocID             Location    Year AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0          4          Afghanistan  2010.0    0-4          0.0         5.0
# 1          8              Albania  2010.0    0-4          0.0         5.0
# 2         12              Algeria  2010.0    0-4          0.0         5.0
# 3         24               Angola  2010.0    0-4          0.0         5.0
# 4         28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 41790    430              Liberia  2019.0   100+        100.0        -1.0
# 41791    882                Samoa  2019.0   100+        100.0        -1.0
# 41792    768                 Togo  2019.0   100+        100.0        -1.0
# 41793    776                Tonga  2019.0   100+        100.0        -1.0
# 41794    548              Vanuatu  2019.0   100+        100.0        -1.0
#
#            Male    Female  PopTotal
# 0      2715.070  2600.535  5315.605
# ...

# %%
pop_2010_2019_df['AgeGrp'].unique()
# Out:
# <StringArray>
# [      '0-4',   '05. Sep',    'Okt 14',     '15-19',     '20-24',     '25-29',
#      '30-34',     '35-39',     '40-44',     '45-49',     '50-54',     '55-59',
#      '60-64',     '65-69',     '70-74',     '75-79',     '80-84',     '85-89',
#      '90-94', '905. Sep9',      '100+']
# Length: 21, dtype: str

# %%
pop_2010_2019_df.replace({'AgeGrp':{'05. Sep':'5-10','Okt 14':'11-14','905. Sep9':'95-99','100+':'100-104'}},inplace=True)
pop_2010_2019_df.head()
# Out:
#    LocID             Location    Year AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
#
#        Male    Female  PopTotal
# 0  2715.070  2600.535  5315.605
# 1    92.622    81.239   173.861
# 2  1966.415  1885.869  3852.284
# 3  2233.041  2239.035  4472.076
# 4     3.543     3.436     6.979

# %%
pop_2010_2019_df['AgeGrp'].unique()
# Out:
# <StringArray>
# [    '0-4',    '5-10',   '11-14',   '15-19',   '20-24',   '25-29',   '30-34',
#    '35-39',   '40-44',   '45-49',   '50-54',   '55-59',   '60-64',   '65-69',
#    '70-74',   '75-79',   '80-84',   '85-89',   '90-94',   '95-99', '100-104']
# Length: 21, dtype: str

# %% [markdown]
# **D. Data Transformation**
# * **.groupby():** Groups data by a column to perform aggregations.
#
# --SQL Equivalent: GROUP BY.
#
# * **.sort_values():** Sorts the data by one or more columns.
#
# --SQL Equivalent: ORDER BY.
#
# * **.apply():** Applies a function (like a Lambda) to every element in a column.
#
# --Power BI Equivalent: Custom Column using Power Query M.

# %%
pop_2010_2019_df.head(10)
# Out:
#    LocID             Location    Year AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# 5     32            Argentina  2010.0    0-4          0.0         5.0
# 6     51              Armenia  2010.0    0-4          0.0         5.0
# 7    533                Aruba  2010.0    0-4          0.0         5.0
# 8     36            Australia  2010.0    0-4          0.0         5.0
# 9     40              Austria  2010.0    0-4          0.0         5.0
#
#        Male    Female  PopTotal
# 0  2715.070  2600.535  5315.605
# 1    92.622    81.239   173.861
# 2  1966.415  1885.869  3852.284
# 3  2233.041  2239.035  4472.076
# ...

# %%
pop_2010_2019_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 41791 entries, 0 to 41794
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        41791 non-null  int64
#  1   Location     41791 non-null  str
#  2   Year         41791 non-null  float64
#  3   AgeGrp       41791 non-null  str
#  4   AgeGrpStart  41791 non-null  float64
#  5   AgeGrpSpan   41791 non-null  float64
#  6   Male         41791 non-null  float64
#  7   Female       41791 non-null  float64
#  8   PopTotal     41791 non-null  float64
# dtypes: float64(6), int64(1), str(2)
# memory usage: 3.2 MB

# %%
##pop_2010_2019_df['Year'] = pd.to_datetime(pop_2010_2019_df['Year'], format='%Y')
#  ---It give 01-01 date to all the rows which is wrong

# %%
pop_2010_2019_df['Year'] = pop_2010_2019_df['Year'].astype(int)
pop_2010_2019_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 41791 entries, 0 to 41794
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        41791 non-null  int64
#  1   Location     41791 non-null  str
#  2   Year         41791 non-null  int64
#  3   AgeGrp       41791 non-null  str
#  4   AgeGrpStart  41791 non-null  float64
#  5   AgeGrpSpan   41791 non-null  float64
#  6   Male         41791 non-null  float64
#  7   Female       41791 non-null  float64
#  8   PopTotal     41791 non-null  float64
# dtypes: float64(5), int64(2), str(2)
# memory usage: 3.2 MB

# %%
pop_2010_2019_df.head(10)
# Out:
#    LocID             Location  Year AgeGrp  AgeGrpStart  AgeGrpSpan      Male  \
# 0      4          Afghanistan  2010    0-4          0.0         5.0  2715.070
# 1      8              Albania  2010    0-4          0.0         5.0    92.622
# 2     12              Algeria  2010    0-4          0.0         5.0  1966.415
# 3     24               Angola  2010    0-4          0.0         5.0  2233.041
# 4     28  Antigua and Barbuda  2010    0-4          0.0         5.0     3.543
# 5     32            Argentina  2010    0-4          0.0         5.0  1836.187
# 6     51              Armenia  2010    0-4          0.0         5.0   107.368
# 7    533                Aruba  2010    0-4          0.0         5.0     3.402
# 8     36            Australia  2010    0-4          0.0         5.0   750.450
# 9     40              Austria  2010    0-4          0.0         5.0   200.530
#
#      Female  PopTotal
# 0  2600.535  5315.605
# 1    81.239   173.861
# 2  1885.869  3852.284
# ...

# %%
pop_2010_2019_df.drop(columns = ['AgeGrpStart','AgeGrpSpan','PopTotal'],inplace = True)
pop_2010_2019_df.head(5)
# Out:
#    LocID             Location  Year AgeGrp      Male    Female
# 0      4          Afghanistan  2010    0-4  2715.070  2600.535
# 1      8              Albania  2010    0-4    92.622    81.239
# 2     12              Algeria  2010    0-4  1966.415  1885.869
# 3     24               Angola  2010    0-4  2233.041  2239.035
# 4     28  Antigua and Barbuda  2010    0-4     3.543     3.436

# %%
pop_2010_2019_df.describe()
# Out:
#               LocID          Year          Male        Female
# count  41791.000000  41791.000000  41791.000000  41791.000000
# mean     443.710631   2014.499892    878.579738    863.585655
# std      275.313265      2.872366   4280.236638   3978.122164
# min        4.000000   2010.000000      0.000000      0.000000
# 25%      218.000000   2012.000000      8.154500     10.138500
# 50%      428.000000   2014.000000     87.610000     99.380000
# 75%      662.000000   2017.000000    415.091000    434.783500
# max     1835.000000   2019.000000  67528.067000  62954.207000

# %%
#pop_2010_2019_df.to_csv('cleaned_data/pop_2010_2019_cleanfile.csv',index=False)
