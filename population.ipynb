# %% [markdown]
# # Load all population Data

# %%
import pandas as pd

pop_2010_2019_df = pd.read_csv('population-2010-2019.csv',skiprows=1,header = 1,index_col=0)

pop_2010_2019_df
# Out:
#                   Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan   PopMale  \
# LocID
# 4              Afghanistan  2010.0    0-4          0.0         5.0  2715.070
# 8                  Albania  2010.0    0-4          0.0         5.0    92.622
# 12                 Algeria  2010.0    0-4          0.0         5.0  1966.415
# 24                  Angola  2010.0    0-4          0.0         5.0  2233.041
# 28     Antigua and Barbuda  2010.0    0-4          0.0         5.0     3.543
# ...                    ...     ...    ...          ...         ...       ...
# 430                Liberia  2019.0   100+        100.0        -1.0     0.000
# 882                  Samoa  2019.0   100+        100.0        -1.0     0.000
# 768                   Togo  2019.0   100+        100.0        -1.0     0.000
# 776                  Tonga  2019.0   100+        100.0        -1.0     0.000
# 548                Vanuatu  2019.0   100+        100.0        -1.0     0.000
#
#        PopFemale  PopTotal
# LocID
# 4       2600.535  5315.605
# 8         81.239   173.861
# 12      1885.869  3852.284
# 24      2239.035  4472.076
# 28         3.436     6.979
# ...          ...       ...
# 430        0.000     0.000
# 882        0.000     0.000
# 768        0.000     0.000
# 776        0.000     0.000
# 548        0.000     0.000
#
# [41795 rows x 8 columns]

# %% [markdown]
# # Find data details

# %% [markdown]
# ## 1. Essential Properties (Attributes)
#   Properties tell you something about the data without changing it. You don't use parentheses () with these.
#
#   | Property | Description | SQL/Power BI Equivalent |
# | :--- | :--- | :--- |
# | **`.shape`** | Returns a tuple (rows, columns). | Table Row/Col count |
# | **`.columns`** | Returns the list of column names. | Header Row |
# | **`.index`** | Returns the row labels (usually 0, 1, 2...). | Primary Key/Index |
# | **`.dtypes`** | Shows the data type of each column. | Schema / Data Category |
# | **`.size`** | Total number of elements (rows × columns). | Total Cell Count |
# | **`.values`** | Converts the data into a NumPy array. | Raw Data Array |

# %%
pop_2010_2019_df.shape
# Out:
# (41795, 8)
